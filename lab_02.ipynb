# %% [markdown]
# <a href="https://colab.research.google.com/github/96kasun/Labs/blob/main/lab_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 02 - Multi-Objective Optimization
# ## Tasks
# - Learn to solve optimization problems using the Xopt package
# - Conduct multi-objective optimization on AWA photoinjector example

# %% [markdown]
# ## Set up environment

# %%
# !pip install xopt==2.5.2
# !pip install pygmo
# Out:
# Collecting xopt==2.5.2
#   Downloading xopt-2.5.2.tar.gz (915 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.3/915.3 kB 7.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting deap (from xopt==2.5.2)
#   Downloading deap-1.4.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from xopt==2.5.2) (2.1.3)
# Requirement already satisfied: pydantic>=2.3 in /usr/local/lib/python3.13/dist-packages (from xopt==2.5.2) (2.13.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from xopt==2.5.2) (6.0.3)
# Collecting botorch>=0.12.0 (from xopt==2.5.2)
#   Downloading botorch-0.18.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.13/dist-packages (from xopt==2.5.2) (1.16.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from xopt==2.5.2) (2.2.3)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.13/dist-packages (from xopt==2.5.2) (7.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from xopt==2.5.2) (4.67.3)
# Requirement already satisfied: orjson in /usr/local/lib/python3.13/dist-packages (from xopt==2.5.2) (3.12.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from xopt==2.5.2) (3.10.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.13/dist-packages (from botorch>=0.12.0->xopt==2.5.2) (4.16.0)
# Collecting pyre_extensions (from botorch>=0.12.0->xopt==2.5.2)
#   Downloading pyre_extensions-0.0.32-py3-none-any.whl.metadata (4.0 kB)
# Collecting gpytorch>=1.15.2 (from botorch>=0.12.0->xopt==2.5.2)
#   Downloading gpytorch-1.15.2-py3-none-any.whl.metadata (8.2 kB)
# Collecting linear_operator>=0.6.1 (from botorch>=0.12.0->xopt==2.5.2)
#   Downloading linear_operator-0.6.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=2.4 in /usr/local/lib/python3.13/dist-packages (from botorch>=0.12.0->xopt==2.5.2) (2.11.0+cpu)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.13/dist-packages (from botorch>=0.12.0->xopt==2.5.2) (1.0.0)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.13/dist-packages (from botorch>=0.12.0->xopt==2.5.2) (3.7.0)
# Collecting ninja (from botorch>=0.12.0->xopt==2.5.2)
#   Downloading ninja-1.13.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.3->xopt==2.5.2) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.3->xopt==2.5.2) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.3->xopt==2.5.2) (0.4.4)
# Collecting moocore (from deap->xopt==2.5.2)
#   Downloading moocore-0.3.2-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.13/dist-packages (from ipywidgets->xopt==2.5.2) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets->xopt==2.5.2) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.13/dist-packages (from ipywidgets->xopt==2.5.2) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets->xopt==2.5.2) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets->xopt==2.5.2) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets->xopt==2.5.2) (3.0.17)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->xopt==2.5.2) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->xopt==2.5.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->xopt==2.5.2) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->xopt==2.5.2) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->xopt==2.5.2) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->xopt==2.5.2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->xopt==2.5.2) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->xopt==2.5.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->xopt==2.5.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->xopt==2.5.2) (2026.4)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in /usr/local/lib/python3.13/dist-packages (from gpytorch>=1.15.2->botorch>=0.12.0->xopt==2.5.2) (1.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.13/dist-packages (from gpytorch>=1.15.2->botorch>=0.12.0->xopt==2.5.2) (1.6.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets->xopt==2.5.2) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets->xopt==2.5.2) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets->xopt==2.5.2) (0.2.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets->xopt==2.5.2) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets->xopt==2.5.2) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets->xopt==2.5.2) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets->xopt==2.5.2) (6.5.7)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.13/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (80.10.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->xopt==2.5.2)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.13/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.13/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (3.0.53)
# Requirement already satisfied: pygments in /usr/local/lib/python3.13/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (2.21.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.13/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.13/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (4.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib->xopt==2.5.2) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=2.4->botorch>=0.12.0->xopt==2.5.2) (3.32.7)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.4->botorch>=0.12.0->xopt==2.5.2) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.4->botorch>=0.12.0->xopt==2.5.2) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=2.4->botorch>=0.12.0->xopt==2.5.2) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.4->botorch>=0.12.0->xopt==2.5.2) (2025.12.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.13/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (6.5.7)
# Requirement already satisfied: cffi>=1.17.1 in /usr/local/lib/python3.13/dist-packages (from moocore->deap->xopt==2.5.2) (2.1.1)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.13/dist-packages (from moocore->deap->xopt==2.5.2) (4.11.8)
# Collecting typing-inspect (from pyre_extensions->botorch>=0.12.0->xopt==2.5.2)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.17.1->moocore->deap->xopt==2.5.2) (3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.13/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->xopt==2.5.2) (0.8.7)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.13/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->xopt==2.5.2) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.13/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->xopt==2.5.2) (5.9.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (5.11.1)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (7.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.26.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.3.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.13/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->xopt==2.5.2) (0.7.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.13/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->xopt==2.5.2) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=2.4->botorch>=0.12.0->xopt==2.5.2) (3.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn->gpytorch>=1.15.2->botorch>=0.12.0->xopt==2.5.2) (1.6.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect->pyre_extensions->botorch>=0.12.0->xopt==2.5.2)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn->gpytorch>=1.15.2->botorch>=0.12.0->xopt==2.5.2) (3.1.2)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.13/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (3.3.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.13/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (2.22.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.13/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.13/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (26.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.13/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.6.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (2026.6.3)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.13/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (2.20.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (2.9.2)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (4.15.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.5.4)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.9.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (3.19)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (4.2.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.13/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.13/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.4.0)
# Downloading botorch-0.18.1-py3-none-any.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 77.2 MB/s eta 0:00:00
# Downloading deap-1.4.4-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 9.3 MB/s eta 0:00:00
# Downloading gpytorch-1.15.2-py3-none-any.whl (291 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.2/291.2 kB 23.4 MB/s eta 0:00:00
# Downloading linear_operator-0.6.1-py3-none-any.whl (174 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.8/174.8 kB 14.8 MB/s eta 0:00:00
# Downloading moocore-0.3.2-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (879 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.5/879.5 kB 47.9 MB/s eta 0:00:00
# Downloading ninja-1.13.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 16.4 MB/s eta 0:00:00
# Downloading pyre_extensions-0.0.32-py3-none-any.whl (12 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 71.4 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Building wheels for collected packages: xopt
#   Building wheel for xopt (pyproject.toml) ... done
#   Created wheel for xopt: filename=xopt-2.5.2-py3-none-any.whl size=186515 sha256=35b934462fabfda97bb0f9de98e3f0f09840b9c6ac66bfee451c2ae17dc3425f
#   Stored in directory: /root/.cache/pip/wheels/fb/97/e3/eb7890f29605be03160e79a7690e99a18517848264122a77c3
# Successfully built xopt
# Installing collected packages: ninja, mypy-extensions, jedi, typing-inspect, moocore, pyre_extensions, linear_operator, deap, gpytorch, botorch, xopt
# Successfully installed botorch-0.18.1 deap-1.4.4 gpytorch-1.15.2 jedi-0.20.0 linear_operator-0.6.1 moocore-0.3.2 mypy-extensions-1.1.0 ninja-1.13.2 pyre_extensions-0.0.32 typing-inspect-0.9.0 xopt-2.5.2
# Collecting pygmo
#   Downloading pygmo-2.19.8-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from pygmo) (2.1.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.13/dist-packages (from pygmo) (3.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from pygmo) (1.16.3)
# Downloading pygmo-2.19.8-cp313-cp313-manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 68.4 MB/s eta 0:00:00
# Installing collected packages: pygmo
# Successfully installed pygmo-2.19.8

# %%
# %reset -f
from google.colab import drive
import os

drive.mount('/content/drive')
path = '/content/drive/MyDrive/Colab Notebooks/'
os.chdir(path)
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 'Copy of lab_01.ipynb'	 data.npy   lab_02.ipynb   Untitled  'Untitled (1)'

# %%
import numpy as np
import matplotlib.pyplot as plt
import xopt

import torch

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# # Multi-objective optimization of a test problem

# %% [markdown]
# Our goal is to find the ideal trade-off between two objectives $f_1,f_2$. We will use a problem selected from a collection of test problems known as the ZDT problem suite. The following explaination is from (https://github.com/anyoptimization/pymoo/blob/main/docs/source/problems/multi/zdt.ipynb) which discusses the entire collection.
#
# ### ZDT
#
# The ZDT <cite data-cite="zdt"></cite> problem suite is based on the construction process
#
# \begin{align}
# \begin{split}
# \min && \; f_1(x)\\
# \min && \; f_2(x) = g(x) \, h(f_1(x),g(x))
# \end{split}
# \end{align}
#
# where two objective have to be minimized. The function $g(x)$ can be considered as the function for convergenece  and usually $g(x) = 1$ holds for pareto-optimal solutions (except for ZDT5).
#
# ### ZDT1
#
# This is a n-D variable problem (here we will use $n=10$) with a convex Pareto-optimal set:
#
# **Definition**
#
# \begin{align}
# \begin{split}
# f_1(x) &= \, & x_1 \\
# g(x) &=& 1 + \frac{9}{n-1} \; \sum_{i=2}^{n} x_i \\
# h(f_1,g) &=& 1 - \sqrt{f_1/g} \\
# \end{split}
# \end{align}
#
#
# $$0 \leq x_i \leq 1 \quad i=1,\ldots,n$$
#
# **Optimum**
#
# $$0 \leq x_1^* \leq 1  \quad \text{and} \quad x_i^*=0 \; \text{for} \; i=2,\ldots,n$$

# %% [markdown]
# To solve this problem we will use the evolutionary CNSGA algorithm, implmented in Xopt.

# %% [markdown]
# ## Defining the problem in Xopt
#
# Xopt can interface with arbitrary evaluate functions (defined in Python) with the
# following form:
# ```python
# def evaluate(inputs: dict) -> dict:
#     """ your code here """
# ```
# Evaluate functions must accept a dictionary object that **at least** has the keys
# specified in `variables, constants` and returns a dictionary
# containing **at least** the
# keys contained in `objectives, constraints`. Extra dictionary keys are tracked and
# used in the evaluate function but are not modified by xopt.

# %%
from xopt import Evaluator

# define the problem as a python callable
n_dims = 10
def evaluate(input_dict):
    x = np.array([input_dict[f"x{i + 1}"] for i in range(n_dims)])

    f1 = x[0]
    g = 1 + (9 / (n_dims - 1)) * np.sum(x[1:])
    h = 1 - np.sqrt(f1 / g)
    f2 = g * h

    return {"f1": f1, "f2": f2, "g": g}

evaluator = Evaluator(function=evaluate)

# %% [markdown]
# ## Define the variables and objectives
# Next we define the variables and objectives for our problem in a `VOCS` object.

# %%
from xopt import VOCS
vocs = VOCS(
    variables={f"x{i + 1}": [0, 1] for i in range(n_dims)},
    objectives={"f1": "MINIMIZE", "f2": "MINIMIZE"},
)
vocs.model_dump()
# Out:
# {'variables': {'x1': [0.0, 1.0],
#   'x2': [0.0, 1.0],
#   'x3': [0.0, 1.0],
#   'x4': [0.0, 1.0],
#   'x5': [0.0, 1.0],
#   'x6': [0.0, 1.0],
#   'x7': [0.0, 1.0],
#   'x8': [0.0, 1.0],
#   'x9': [0.0, 1.0],
#   'x10': [0.0, 1.0]},
#  'constraints': {},
#  'objectives': {'f1': 'MINIMIZE', 'f2': 'MINIMIZE'},
#  'constants': {},
#  'observables': []}

# %% [markdown]
# ## Define the optimization algorithm

# %%
from xopt.generators.ga import CNSGAGenerator
generator = CNSGAGenerator(
    vocs=vocs,
    population_size=64,
    crossover_probability=0.75,
    mutation_probability=0.25
)
generator.model_dump()
# Out:
# {'population_size': 64,
#  'crossover_probability': 0.75,
#  'mutation_probability': 0.25,
#  'population_file': None,
#  'output_path': None,
#  'population': None}

# %% [markdown]
# ## Combine the evaluator, vocs, and generator objects into the Xopt object

# %%
from xopt import Xopt
X = Xopt(
    vocs=vocs,
    generator=generator,
    evaluator=evaluator
)

# %%
generations = 100
for _ in range(64 * generations):
    X.step()

# %%
X.data.plot.scatter(x="f1",y="f2",c=X.data.index,cmap="viridis")
# Out:
# <Axes: xlabel='f1', ylabel='f2'>

# %% [markdown]
# > ### **Task**
# > Plot the Pareto front and calculate the front hypervolume with the reference point (11,11). See `fast_non_dominated_sorting` in https://esa.github.io/pygmo2/tutorials/moo.html and `hypervolume` in https://esa.github.io/pygmo2/tutorials/hypervolume.html .

# %%
import pygmo as pg
import matplotlib.pyplot as plt

# Extract objective values
f_values = X.data[['f1', 'f2']].to_numpy()

# Perform non-dominated sorting to find the Pareto front
# pg.fast_non_dominated_sorting returns a tuple (list_of_front_indices, list_of_dominance_levels, list_of_crowding_distances)
# We need the first element (list_of_front_indices), and from that, the first sub-list (the Pareto front indices).
all_fronts_indices = pg.fast_non_dominated_sorting(f_values)[0]
pareto_front_indices = all_fronts_indices[0]
pareto_front = f_values[pareto_front_indices]

# Plot the Pareto front
plt.figure(figsize=(8, 6))
plt.scatter(f_values[:, 0], f_values[:, 1], label='All Solutions', alpha=0.5)
plt.scatter(pareto_front[:, 0], pareto_front[:, 1], color='red', label='Pareto Front')
plt.xlabel('f1')
plt.ylabel('f2')
plt.title('Optimization Results with Pareto Front')
plt.legend()
plt.grid(True)
plt.show()

# Calculate hypervolume
ref_point = [11.0, 11.0]  # Reference point (11,11) as requested
hv = pg.hypervolume(pareto_front) # Pass the actual Pareto front points
hv_value = hv.compute(ref_point)

print(f"The hypervolume of the Pareto front with reference point {ref_point} is: {hv_value}")
# Out:
# The hypervolume of the Pareto front with reference point [11.0, 11.0] is: 120.47386897302864

# %% [markdown]
# # Multi-objective optimization of the AWA photoinjector

# %% [markdown]
# Here we will find the pareto front of the AWA photoinjector problem (see below).
# Input variables are shown in red and output variables are shown in blue. Both the
# inputs and outputs are normalized to [-1,1]. Our goal is to minimize all of the
# output beam parameters. To model the AWA beamline dynamics we use a pre-compiled, fast
# executing neural network surrogate model (that you will have a chance to build in lab
#  5!). The inputs to this model are `[P0, P1, G0, G1, K1, K2]` and the outputs are
#  `[rms_x, rms_y, rms_s, emit_x, emit_y, emit_s, dE]`.
#
#
#
# ![Figure5.png](data:image/png;base64,...)

# %%
# get AWA model
awa_model = torch.jit.load("awa_model.pt")

# test awa_model
x = torch.rand(6)
awa_model(x)

# %%
# define variables and objectives in VOCS object
awa_vocs = VOCS(
    variables={
        'P0':[-1.0,1.0],
        'P1':[-1.0,1.0],
        'G0':[-1.0,1.0],
        'G1':[-1.0,1.0],
        'K1':[-1.0,1.0],
        'K2':[-1.0,1.0]
    },
    objectives={
        'rms_x':"MINIMIZE",
        'rms_y':"MINIMIZE",
        'rms_s':"MINIMIZE",
        'emit_x':"MINIMIZE",
        'emit_y':"MINIMIZE",
        'emit_s':"MINIMIZE",
        'dE':"MINIMIZE"
    }
)

# %% [markdown]
# > ### **Task**
# > Use the above code to find the 7D pareto front of the AWA multi-objective problem. Plot the front projected onto the bunch length vs. horizontal emittance subspace.
#
# > Note: when evaluating the NN model, you should call `detach().numpy()` to convert the output of the model into a numpy array.

# %% [markdown]
# # **Homework**
# Another approach to solving multi-objective problems is to specify explicit weights that rate the relative importance of each objective. In this case the problem is single objective and can be solved by a variety of single objective algorithms, including RCDS. Use the Xopt `RCDSGenerator` generator (see https://xopt.xopt.org/examples/rcds/rcds/ for an example) to solve for multiple different objective trade-offs of the ZDT1 problem
# - even weighting between all objectives
# - weight `f1 = 2*f2` with all others equal weighting with respect to rms_s
# - weight `f2 = 2*f1` with all others equal weighting with respect to rms_s
#
# Plot the `f1,f2` function values found to minimize the three problems on an axis that also contains the ZDT1 pareto front. How do these solutions compare to the Pareto front in objective space?
